# %%
## Name: Pham Minh Quang
## ID: 19522099
## Link github: https://github.com/minhquang2001/MKTG5883.N22.CTTT

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import numpy as np
x = np.linspace(0, 5, 11)
y = x ** 2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
plt.plot(x, y, 'r') # 'r' is the color red
plt.xlabel('X Axis Title Here')
plt.ylabel('Y Axis Title Here')
plt.title('String Title Here')
plt.show()

# %%
# plt.subplot(nrows, ncols, plot_number)
plt.subplot(1,2,1)
plt.plot(x, y, 'r--') # More on color options later
plt.subplot(1,2,2)
plt.plot(y, x, 'g*-')

# %%
# Create Figure (empty canvas)
fig = plt.figure()

# Add set of axes to figure 
axes = fig.add_axes([0.1, 0.1, 0.8, 0.8]) #left, bottom, width, height

#Plot on that set of axes
axes.plot(x, y, 'b')
axes.set_xlabel('Set X Label') # Notice the use of set_ to begin methods
axes.set_ylabel('Set Y Label')
axes.set_title('Set Title')
# Out:
# Text(0.5, 1.0, 'Set Title')

# %%
# Creates blank canvas 
fig = plt.figure()

axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8]) #main axes
axes2 = fig.add_axes([0.2, 0.5, 0.4, 0.3]) #inset axes

# Larger Figure Axes 1
axes1.plot(x, y, 'b')
axes1.set_xlabel('X_label_axes2')
axes1.set_ylabel('Y_label_axes2')
axes1.set_title('Axes 2 Title')

# Insert Figure Axes 2
axes2.plot(y, x, 'r')
axes2.set_xlabel('X_label_axes2')
axes2.set_ylabel('Y_label_axes2')
axes2.set_title('Axes 2 Title')
# Out:
# Text(0.5, 1.0, 'Axes 2 Title')

# %%
# Use similar to plt.figure() except use tuple unpacking to grab fix and axes
fig, axes = plt.subplots()

# Now use the axes object to add stuff to plot
axes.plot(x, y, 'r')
axes.set_xlabel('x')
axes.set_ylabel('y')
axes.set_title('title')
# Out:
# Text(0.5, 1.0, 'title')

# %%
# Empty canvas of 1 by 2 subplots
fig, axes = plt.subplots(nrows=1, ncols=2)

# %%
# Axes is an array of axes to plot on
axes
# Out:
# array([<Axes: >, <Axes: >], dtype=object)

# %%
for ax in axes:
  ax.plot(x, y, 'b')
  ax.set_xlabel('x')
  ax.set_ylabel('y')
  ax.set_title('title')

# Display the figure object
fig

# %%
fig, axes = plt.subplots(nrows = 1, ncols = 2)

for ax in axes:
  ax.plot(x, y, 'g')
  ax.set_xlabel('x')
  ax.set_ylabel('y')
  ax.set_title('title')

fig
plt.tight_layout()

# %%
fig = plt.figure(figsize=(8,4), dpi = 100)

# %%
fig, axes = plt.subplots(figsize=(12,3))

axes.plot(x, y, 'r')
axes.set_xlabel('x')
axes.set_ylabel('y')
axes.set_title('title')
# Out:
# Text(0.5, 1.0, 'title')

# %%
fig.savefig('filename.png')

# %%
fig.savefig("filename.png", dpi=200)

# %%
ax.set_title('title')
# Out:
# Text(0.5, 1.0, 'title')

# %%
ax.set_xlabel('x')
ax.set_ylabel('y')
# Out:
# Text(336.49999999999994, 0.5, 'y')

# %%
fig = plt.figure()

ax = fig.add_axes([0, 0, 1, 1])

ax.plot(x, x**2, label='x**2')
ax.plot(x, x**3, label='x**3')
ax.legend()

# %%
fig, axes = plt.subplots(1, 3, figsize=(12, 4))

axes[0].plot(x, x**2, x, x**3)
axes[0].set_title('default axes ranges')

axes[1].plot(x, x**2, x, x**3)
axes[1].axis('tight')
axes[1].set_title('tight axes')

axes[2].plot(x, x**2, x, x**3)
axes[2].set_ylim([0, 60])
axes[2].set_xlim([2, 5])
axes[2].set_title('custom axes range')
# Out:
# Text(0.5, 1.0, 'custom axes range')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import seaborn as sns
# %matplotlib inline

sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
ax = sns.scatterplot(x='total_bill', y='tip', data=tips)

# %%
sns.relplot(x='total_bill', y='tip', data=tips, kind='scatter',
            hue='sex', size='size',
            )

# %%
sns.catplot(x='sex', y='total_bill', hue='day', data=tips, kind='strip')

# %%
sns.catplot(x='sex', y='total_bill', hue='day', data=tips, kind='strip',
            jitter=False, dodge= True)

# %%
sns.catplot(x='sex', y='total_bill', hue='day', data=tips, kind='box')

# %%
tips = pd.read_csv('job-market.csv', error_bad_lines=False, encoding='utf-8')
order = tips['Classification'].value_counts().index.tolist()
sns.countplot(y='Classification', data=tips, order = order, width=0.5)
plt.tick_params(axis='y', which='major', pad=0.5)
plt.xlabel('Number of Jobs')
plt.title('Number of Jobs by Classification')
# Out:
# <ipython-input-65-3ff30f386e75>:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   tips = pd.read_csv('job-market.csv', error_bad_lines=False, encoding='utf-8')
# Text(0.5, 1.0, 'Number of Jobs by Classification')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Đọc dữ liệu từ file CSV
df = pd.read_csv('job-market.csv')

# Tính range của cột dữ liệu salary
salary_range = df['HighestSalary'].max() - df['HighestSalary'].min()
print('Salary range:', salary_range)

# Tính phần trăm của từng giá trị salary
salary_pct = df['HighestSalary'].value_counts(normalize=True) * 100

index = df['HighestSalary'].nunique()
opacity = [0.5 for i in range(index)]
print('Salary range:', opacity)


# Vẽ biểu đồ pie chart
plt.pie(salary_pct, labels=salary_pct.index, autopct='%1.1f%%',pctdistance=0.75,  wedgeprops={"alpha": 0.5})
plt.axis('equal')
plt.title('Salary distribution')

# Vẽ vòng tròn giữa để tạo thành biểu đồ tròn
centre_circle = plt.Circle((0,0),0.50,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

plt.show()
# Out:
# Salary range: 30.0
# Salary range: [0.5, 0.5, 0.5, 0.5]
